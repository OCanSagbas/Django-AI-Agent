# %%
import os
import sys
import django

# Async güvensiz modunu etkinleştir
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# Django projesinin path'ini ekle
sys.path.append('/home/ocans/DJANGO-AI-AGENT/src')

# Django settings'i tanımla
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'cfehome.settings')

# Django'yu başlat
django.setup()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: cfe>, <User: staff>]>

# %%
user_obj = User(
    username="staff"
)

#user_obj.save()

# %%
from documents.models import Document

doc_obj = Document(
    owner=user_obj,
    title="Test Document"
)
doc_obj
# Out:
# <Document: Test Document>

# %%
#doc_obj.save()
doc_obj
# Out:
# <Document: Test Document>

# %%
user_obj = User.objects.first()
print(user_obj)
user_obj = User.objects.last()
print(user_obj)
# Out:
# cfe
# staff

# %%
#Basic creation part of the user
user_obj = User.objects.create(
    username="ocansagbas"
)
# Out:
# <User: ocansagbas>

# %%
help(User)

# %%
#Basic permission part of the user
user_obj = User.objects.get(
    username="ocansagbas"
)
user_obj.is_staff=True
user_obj.set_password("1614")
user_obj.save()
print(user_obj.password)
user_obj.is_staff
# Out:
# pbkdf2_sha256$1000000$lNf1OsAs52H5bNDeusoE4i$GIQJkbKI1zkoNyCV0GWPsZZnYEAIjjncZAouszqLZLE=
# True
